# %% [markdown]
# # Mounting drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Importing libraries

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

from sklearn import metrics
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import KFold
from collections import Counter

# %% [markdown]
# # Hyperparameter for keras model an tensorflow tokenizer and cross validation

# %%
vocab_size = 45000
embedding_dim = 18
max_length = 0
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"

# %% [markdown]
# # Reading datasets from drive

# %%
dataSet1 = pd.read_csv('/content/drive/MyDrive/Medical Misinformation Detection Model/Datasets/Created Dataset/article_and_tweets_with_cleaning.csv', sep = ",")
dataSet2 = pd.read_csv('/content/drive/MyDrive/Medical Misinformation Detection Model/Datasets/Created Dataset/article_and_tweets_without_cleaning.csv', sep = ",")
dataSet3 = pd.read_csv('/content/drive/MyDrive/Medical Misinformation Detection Model/Datasets/Created Dataset/tweets_with_cleaning.csv', sep = ",")
dataSet4 = pd.read_csv('/content/drive/MyDrive/Medical Misinformation Detection Model/Datasets/Created Dataset/tweets_without_cleaning.csv', sep = ",")
dataSet_array = [dataSet1, dataSet2, dataSet3, dataSet4]

# %% [markdown]
# # Defining plot graphs method

# %%
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

# %% [markdown]
# # Experiment

# %%
sub_experiment_count = 1
accuracy  = 0
recall    = 0
f1_score  = 0
precision = 0
for dataSet in dataSet_array:
  dataSet_text = dataSet['text']
  dataSet_label = dataSet['label']
  sub_accuracy  = 0
  sub_recall    = 0
  sub_f1_score  = 0
  sub_precision = 0
  print('------------------------------------------------------------')
  #change the maxlen value
  if sub_experiment_count == 1:
    print('!!!!!  sub-experiment with keras sequential model number 1 !!!!!')
    print('!!!!!  dataset used is : article and tweets with cleaning  !!!!!')
    max_length = 2000
  elif sub_experiment_count == 2:
    print('!!!!!  sub-experiment with keras sequential model number 2  !!!!!')
    print('!!!!!  dataset used is : article and tweets without cleaning  !!!!!')
    max_length = 2000
  elif sub_experiment_count == 3:
    print('!!!!!  sub-experiment with keras sequential model number 3  ')
    print('!!!!!  dataset used is : tweets with cleaning  !!!!!')
    max_length = 250
  elif sub_experiment_count == 4:
    print('!!!!!  sub-experiment with keras sequential model number 4  !!!!!')
    print('!!!!!  dataset used is : tweets without cleaning  !!!!!')
    max_length = 250
  print('------------------------------------------------------------')
  
  #cross validation counter
  split = 1
  kfold = KFold(n_splits=10, shuffle=True)

  #cross validation loop
  for train, test in kfold.split(dataSet_text, dataSet_label):
    #create the tokenizer and fit the tokenizer dictionary
    tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
    tokenizer.fit_on_texts(dataSet_text[train])
    #convert texts to sequences
    training_sequences = tokenizer.texts_to_sequences(dataSet_text[train])
    testing_sequences = tokenizer.texts_to_sequences(dataSet_text[test])
    #make the sequences in the same length
    training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)    
    testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)
    
    #convert the vectors to np array
    training_padded = np.array(training_padded)
    training_labels = np.array(dataSet_label[train])
    testing_padded = np.array(testing_padded)
    testing_labels = np.array(dataSet_label[test])

    #some output
    print('             !!!!!  split number : '+ str(split) + '  !!!!!')
    print('     ' + f'In training: {Counter(training_labels)}')
    print('     ' + f'In testing: {Counter(testing_labels)}')

    #create the keras model with 4 layers
    model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
    ])

    #create the metrics array
    metrics_array = [
        tf.keras.metrics.BinaryAccuracy(name='accuracy'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    #compile the model
    model.compile(loss='binary_crossentropy',optimizer='adam',metrics=metrics_array)

    #model training with 15 epochs
    history = model.fit(training_padded, training_labels, epochs=15, validation_data=(testing_padded, testing_labels), verbose=2)

    #call the method plot_graphs for some statistic
    plot_graphs(history, "accuracy")
    plot_graphs(history, "loss")
    
    # testing the model
    lable_predicted = model.predict(testing_padded)
    lable_predicted = lable_predicted.flatten()
    lable_predicted = np.where(lable_predicted > 0.5, 1, 0)

    # create and show the confusion matrix
    cm = metrics.confusion_matrix(testing_labels, lable_predicted)
    sn.heatmap(cm, annot=True, fmt='d')
    plt.xlabel('Predicted')
    plt.ylabel('Truth')
    plt.show()
    
    #show the classification report 
    print(metrics.classification_report(testing_labels, lable_predicted))

    #add the new metrics result from the new cross val. to the old  metrics result from the old cross val.
    sub_accuracy  = sub_accuracy + metrics.accuracy_score(testing_labels, lable_predicted)
    sub_recall    = sub_recall + metrics.recall_score(testing_labels, lable_predicted)
    sub_f1_score  = sub_f1_score + metrics.f1_score(testing_labels, lable_predicted)
    sub_precision = sub_precision + metrics.precision_score(testing_labels, lable_predicted)

    #indexing
    split = split + 1
  #compute the mean of the using metrics in the cross val.
  sub_accuracy  = sub_accuracy / 10
  sub_recall    = sub_recall / 10
  sub_f1_score  = sub_f1_score / 10
  sub_precision = sub_precision / 10

  #some output
  print("mean accuracy for this sub_experiment is " + str(round(sub_accuracy, 2)))
  print("mean recall for this sub_experiment is " + str(round(sub_recall, 2)))
  print("mean precision for this sub_experiment is " + str(round(sub_precision, 2)))
  print("mean f1_score for this sub_experiment is " + str(round(sub_f1_score, 2)))

  #add the new metrics result from the new sub experiment to the old  metrics result from the old sub experiments
  accuracy  = accuracy + sub_accuracy
  recall    = recall + sub_recall
  precision = precision + sub_precision
  f1_score  = f1_score + sub_f1_score

  #indexing
  sub_experiment_count = sub_experiment_count + 1
  
  

#compute the mean of the using metrics for the 4 sub experiments.
accuracy  = accuracy / 4
recall    = recall / 4
f1_score  = f1_score / 4
precision = precision / 4

#some output
print('---------------------------------------------------------')
print('                   End of Experiment')
print('---------------------------------------------------------')

print("mean accuracy for this experiment is " + str(round(accuracy, 2)))
print("mean recall for this experiment is " + str(round(recall, 2)))
print("mean precision for this experiment is " + str(round(precision, 2)))
print("mean f1_score for this experiment is " + str(round(f1_score, 2)))
# Out:
# ------------------------------------------------------------
# !!!!!  sub-experiment with keras sequential model number 1 !!!!!
# !!!!!  dataset used is : article and tweets with cleaning  !!!!!
# ------------------------------------------------------------
#              !!!!!  split number : 1  !!!!!
#      In training: Counter({True: 9892, False: 9855})
#      In testing: Counter({False: 1116, True: 1079})
# Epoch 1/15
# 618/618 - 11s - loss: 0.6930 - accuracy: 0.5075 - precision: 0.5097 - recall: 0.4436 - val_loss: 0.6923 - val_accuracy: 0.5458 - val_precision: 0.9881 - val_recall: 0.0769 - 11s/epoch - 17ms/step
# Epoch 2/15
# 618/618 - 9s - loss: 0.6875 - accuracy: 0.5562 - precision: 0.5462 - recall: 0.6739 - val_loss: 0.6771 - val_accuracy: 0.7909 - val_precision: 0.8377 - val_recall: 0.7127 - 9s/epoch - 14ms/step
# Epoch 3/15
# 618/618 - 10s - loss: 0.6496 - accuracy: 0.6303 - precision: 0.6135 - recall: 0.7079 - val_loss: 0.6208 - val_accuracy: 0.6943 - val_precision: 0.9232 - val_recall: 0.4124 - 10s/epoch - 16ms/step
# Epoch 4/15
# 618/618 - 9s - loss: 0.5763 - accuracy: 0.7539 - precision: 0.7498 - recall: 0.7636 - val_loss: 0.5527 - val_accuracy: 0.7886 - val_precision: 0.7236 - val_recall: 0.9222 - 9s/epoch - 15ms/step
# Epoch 5/15
# 618/618 - 10s - loss: 0.5079 - accuracy: 0.7963 - precision: 0.8000 - recall: 0.7911 - val_loss: 0.4975 - val_accuracy: 0.7959 - val_precision: 0.9082 - val_recall: 0.6506 - 10s/epoch - 16ms/step
# Epoch 6/15
# 618/618 - 9s - loss: 0.4476 - accuracy: 0.8395 - precision: 0.8476 - recall: 0.8286 - val_loss: 0.4611 - val_accuracy: 0.8396 - val_precision: 0.7892 - val_recall: 0.9194 - 9s/epoch - 15ms/step
# Epoch 7/15
# 618/618 - 9s - loss: 0.4040 - accuracy: 0.8497 - precision: 0.8544 - recall: 0.8438 - val_loss: 0.4270 - val_accuracy: 0.8633 - val_precision: 0.8343 - val_recall: 0.9008 - 9s/epoch - 15ms/step
# Epoch 8/15
# 618/618 - 9s - loss: 0.3643 - accuracy: 0.8693 - precision: 0.8727 - recall: 0.8652 - val_loss: 0.4079 - val_accuracy: 0.8501 - val_precision: 0.9050 - val_recall: 0.7766 - 9s/epoch - 14ms/step
# Epoch 9/15
# 618/618 - 9s - loss: 0.3344 - accuracy: 0.8797 - precision: 0.8851 - recall: 0.8733 - val_loss: 0.3888 - val_accuracy: 0.8715 - val_precision: 0.8673 - val_recall: 0.8721 - 9s/epoch - 14ms/step
# Epoch 10/15
# 618/618 - 9s - loss: 0.3069 - accuracy: 0.8911 - precision: 0.8952 - recall: 0.8864 - val_loss: 0.4222 - val_accuracy: 0.8405 - val_precision: 0.7780 - val_recall: 0.9453 - 9s/epoch - 15ms/step
# Epoch 11/15
# 618/618 - 10s - loss: 0.2816 - accuracy: 0.9011 - precision: 0.9061 - recall: 0.8955 - val_loss: 0.3801 - val_accuracy: 0.8729 - val_precision: 0.8454 - val_recall: 0.9073 - 10s/epoch - 16ms/step
# Epoch 12/15
# 618/618 - 9s - loss: 0.2581 - accuracy: 0.9112 - precision: 0.9150 - recall: 0.9070 - val_loss: 0.3650 - val_accuracy: 0.8811 - val_precision: 0.8858 - val_recall: 0.8703 - 9s/epoch - 14ms/step
# Epoch 13/15
# 618/618 - 9s - loss: 0.2429 - accuracy: 0.9126 - precision: 0.9173 - recall: 0.9073 - val_loss: 0.4851 - val_accuracy: 0.7909 - val_precision: 0.9441 - val_recall: 0.6108 - 9s/epoch - 15ms/step
# Epoch 14/15
# 618/618 - 9s - loss: 0.2286 - accuracy: 0.9180 - precision: 0.9225 - recall: 0.9130 - val_loss: 0.3690 - val_accuracy: 0.8770 - val_precision: 0.8539 - val_recall: 0.9045 - 9s/epoch - 15ms/step
# Epoch 15/15
# 618/618 - 9s - loss: 0.2123 - accuracy: 0.9248 - precision: 0.9304 - recall: 0.9186 - val_loss: 0.3742 - val_accuracy: 0.8747 - val_precision: 0.8466 - val_recall: 0.9101 - 9s/epoch - 14ms/step
#               precision    recall  f1-score   support
#
#        False       0.91      0.84      0.87      1116
#         True       0.85      0.91      0.88      1079
#
#     accuracy                           0.87      2195
#    macro avg       0.88      0.88      0.87      2195
# weighted avg       0.88      0.87      0.87      2195
#
#              !!!!!  split number : 2  !!!!!
#      In training: Counter({True: 9876, False: 9871})
#      In testing: Counter({False: 1100, True: 1095})
# Epoch 1/15
# 618/618 - 10s - loss: 0.6931 - accuracy: 0.5054 - precision: 0.5048 - recall: 0.5850 - val_loss: 0.6931 - val_accuracy: 0.5002 - val_precision: 0.4995 - val_recall: 0.9991 - 10s/epoch - 17ms/step
# Epoch 2/15
# 618/618 - 9s - loss: 0.6906 - accuracy: 0.5272 - precision: 0.5256 - recall: 0.5597 - val_loss: 0.6837 - val_accuracy: 0.5216 - val_precision: 0.9412 - val_recall: 0.0438 - 9s/epoch - 14ms/step
# Epoch 3/15
# 618/618 - 9s - loss: 0.6624 - accuracy: 0.6152 - precision: 0.6132 - recall: 0.6245 - val_loss: 0.6375 - val_accuracy: 0.5818 - val_precision: 0.5460 - val_recall: 0.9598 - 9s/epoch - 14ms/step
# Epoch 4/15
# 618/618 - 10s - loss: 0.5961 - accuracy: 0.7315 - precision: 0.7218 - recall: 0.7535 - val_loss: 0.5827 - val_accuracy: 0.6715 - val_precision: 0.9065 - val_recall: 0.3808 - 10s/epoch - 15ms/step
# Epoch 5/15
# 618/618 - 9s - loss: 0.5240 - accuracy: 0.8044 - precision: 0.8128 - recall: 0.7912 - val_loss: 0.5167 - val_accuracy: 0.8182 - val_precision: 0.8446 - val_recall: 0.7790 - 9s/epoch - 14ms/step
# Epoch 6/15
# 618/618 - 9s - loss: 0.4650 - accuracy: 0.8256 - precision: 0.8349 - recall: 0.8119 - val_loss: 0.5133 - val_accuracy: 0.7526 - val_precision: 0.6806 - val_recall: 0.9498 - 9s/epoch - 14ms/step
# Epoch 7/15
# 618/618 - 9s - loss: 0.4170 - accuracy: 0.8496 - precision: 0.8540 - recall: 0.8436 - val_loss: 0.4521 - val_accuracy: 0.8424 - val_precision: 0.8543 - val_recall: 0.8247 - 9s/epoch - 14ms/step
# Epoch 8/15
# 618/618 - 9s - loss: 0.3765 - accuracy: 0.8669 - precision: 0.8716 - recall: 0.8607 - val_loss: 0.4373 - val_accuracy: 0.8387 - val_precision: 0.8847 - val_recall: 0.7781 - 9s/epoch - 15ms/step
# Epoch 9/15
# 618/618 - 9s - loss: 0.3436 - accuracy: 0.8781 - precision: 0.8841 - recall: 0.8704 - val_loss: 0.4199 - val_accuracy: 0.8528 - val_precision: 0.8594 - val_recall: 0.8429 - 9s/epoch - 15ms/step
# Epoch 10/15
# 618/618 - 10s - loss: 0.3113 - accuracy: 0.8909 - precision: 0.8957 - recall: 0.8850 - val_loss: 0.4230 - val_accuracy: 0.8487 - val_precision: 0.8124 - val_recall: 0.9059 - 10s/epoch - 16ms/step
# Epoch 11/15
# 618/618 - 9s - loss: 0.2895 - accuracy: 0.8943 - precision: 0.8977 - recall: 0.8900 - val_loss: 0.4229 - val_accuracy: 0.8428 - val_precision: 0.9094 - val_recall: 0.7607 - 9s/epoch - 14ms/step
# Epoch 12/15
# 618/618 - 9s - loss: 0.2637 - accuracy: 0.9079 - precision: 0.9129 - recall: 0.9019 - val_loss: 0.4515 - val_accuracy: 0.8269 - val_precision: 0.7682 - val_recall: 0.9352 - 9s/epoch - 14ms/step
# Epoch 13/15
# 618/618 - 9s - loss: 0.2498 - accuracy: 0.9107 - precision: 0.9166 - recall: 0.9036 - val_loss: 0.3988 - val_accuracy: 0.8647 - val_precision: 0.8661 - val_recall: 0.8621 - 9s/epoch - 14ms/step
# Epoch 14/15
# 618/618 - 9s - loss: 0.2300 - accuracy: 0.9204 - precision: 0.9238 - recall: 0.9164 - val_loss: 0.4329 - val_accuracy: 0.8451 - val_precision: 0.9181 - val_recall: 0.7571 - 9s/epoch - 14ms/step
# Epoch 15/15
# 618/618 - 9s - loss: 0.2141 - accuracy: 0.9235 - precision: 0.9270 - recall: 0.9195 - val_loss: 0.4044 - val_accuracy: 0.8679 - val_precision: 0.8794 - val_recall: 0.8521 - 9s/epoch - 14ms/step
#               precision    recall  f1-score   support
#
#        False       0.86      0.88      0.87      1100
#         True       0.88      0.85      0.87      1095
#
#     accuracy                           0.87      2195
#    macro avg       0.87      0.87      0.87      2195
# weighted avg       0.87      0.87      0.87      2195
#
#              !!!!!  split number : 3  !!!!!
#      In training: Counter({True: 9891, False: 9857})
#      In testing: Counter({False: 1114, True: 1080})
# Epoch 1/15
# 618/618 - 10s - loss: 0.6930 - accuracy: 0.5046 - precision: 0.5053 - recall: 0.5143 - val_loss: 0.6923 - val_accuracy: 0.5296 - val_precision: 0.5119 - val_recall: 0.9574 - 10s/epoch - 16ms/step
# Epoch 2/15
# 618/618 - 9s - loss: 0.6897 - accuracy: 0.5511 - precision: 0.5460 - recall: 0.6151 - val_loss: 0.6836 - val_accuracy: 0.5383 - val_precision: 0.9718 - val_recall: 0.0639 - 9s/epoch - 14ms/step
# Epoch 3/15
# 618/618 - 9s - loss: 0.6647 - accuracy: 0.6030 - precision: 0.5932 - recall: 0.6601 - val_loss: 0.6514 - val_accuracy: 0.5510 - val_precision: 0.5237 - val_recall: 0.9713 - 9s/epoch - 15ms/step
# Epoch 4/15
# 618/618 - 10s - loss: 0.6077 - accuracy: 0.7197 - precision: 0.7143 - recall: 0.7339 - val_loss: 0.5880 - val_accuracy: 0.7019 - val_precision: 0.6304 - val_recall: 0.9537 - 10s/epoch - 16ms/step
# Epoch 5/15
# 618/618 - 9s - loss: 0.5426 - accuracy: 0.7810 - precision: 0.7824 - recall: 0.7795 - val_loss: 0.5318 - val_accuracy: 0.8149 - val_precision: 0.7645 - val_recall: 0.9019 - 9s/epoch - 15ms/step
# Epoch 6/15
# 618/618 - 9s - loss: 0.4859 - accuracy: 0.8154 - precision: 0.8248 - recall: 0.8017 - val_loss: 0.5153 - val_accuracy: 0.7685 - val_precision: 0.6962 - val_recall: 0.9398 - 9s/epoch - 14ms/step
# Epoch 7/15
# 618/618 - 9s - loss: 0.4360 - accuracy: 0.8495 - precision: 0.8554 - recall: 0.8417 - val_loss: 0.4724 - val_accuracy: 0.8241 - val_precision: 0.9102 - val_recall: 0.7130 - 9s/epoch - 14ms/step
# Epoch 8/15
# 618/618 - 10s - loss: 0.3958 - accuracy: 0.8638 - precision: 0.8717 - recall: 0.8538 - val_loss: 0.4534 - val_accuracy: 0.8368 - val_precision: 0.9038 - val_recall: 0.7481 - 10s/epoch - 16ms/step
# Epoch 9/15
# 618/618 - 9s - loss: 0.3646 - accuracy: 0.8728 - precision: 0.8793 - recall: 0.8648 - val_loss: 0.4386 - val_accuracy: 0.8551 - val_precision: 0.9053 - val_recall: 0.7880 - 9s/epoch - 15ms/step
# Epoch 10/15
# 618/618 - 9s - loss: 0.3320 - accuracy: 0.8866 - precision: 0.8916 - recall: 0.8806 - val_loss: 0.4543 - val_accuracy: 0.8273 - val_precision: 0.7686 - val_recall: 0.9287 - 9s/epoch - 15ms/step
# Epoch 11/15
# 618/618 - 9s - loss: 0.3098 - accuracy: 0.8928 - precision: 0.8972 - recall: 0.8877 - val_loss: 0.4278 - val_accuracy: 0.8587 - val_precision: 0.8246 - val_recall: 0.9056 - 9s/epoch - 14ms/step
# Epoch 12/15
# 618/618 - 11s - loss: 0.2869 - accuracy: 0.9016 - precision: 0.9063 - recall: 0.8963 - val_loss: 0.4361 - val_accuracy: 0.8528 - val_precision: 0.8080 - val_recall: 0.9194 - 11s/epoch - 17ms/step
# Epoch 13/15
# 618/618 - 11s - loss: 0.2651 - accuracy: 0.9102 - precision: 0.9149 - recall: 0.9049 - val_loss: 0.4133 - val_accuracy: 0.8751 - val_precision: 0.8890 - val_recall: 0.8528 - 11s/epoch - 18ms/step
# Epoch 14/15
# 618/618 - 9s - loss: 0.2479 - accuracy: 0.9159 - precision: 0.9208 - recall: 0.9104 - val_loss: 0.4661 - val_accuracy: 0.8423 - val_precision: 0.7845 - val_recall: 0.9370 - 9s/epoch - 14ms/step
# Epoch 15/15
# 618/618 - 9s - loss: 0.2324 - accuracy: 0.9197 - precision: 0.9234 - recall: 0.9157 - val_loss: 0.4194 - val_accuracy: 0.8833 - val_precision: 0.8705 - val_recall: 0.8963 - 9s/epoch - 14ms/step
#               precision    recall  f1-score   support
#
#        False       0.90      0.87      0.88      1114
#         True       0.87      0.90      0.88      1080
#
#     accuracy                           0.88      2194
#    macro avg       0.88      0.88      0.88      2194
# weighted avg       0.88      0.88      0.88      2194
#
#              !!!!!  split number : 4  !!!!!
#      In training: Counter({True: 9887, False: 9861})
#      In testing: Counter({False: 1110, True: 1084})
# Epoch 1/15
# 618/618 - 11s - loss: 0.6930 - accuracy: 0.5053 - precision: 0.5060 - recall: 0.5021 - val_loss: 0.6923 - val_accuracy: 0.5068 - val_precision: 0.5005 - val_recall: 0.9945 - 11s/epoch - 17ms/step
# Epoch 2/15
# 618/618 - 9s - loss: 0.6891 - accuracy: 0.5402 - precision: 0.5368 - recall: 0.5952 - val_loss: 0.6810 - val_accuracy: 0.5583 - val_precision: 0.9832 - val_recall: 0.1079 - 9s/epoch - 14ms/step
# Epoch 3/15
# 618/618 - 9s - loss: 0.6622 - accuracy: 0.6236 - precision: 0.6117 - recall: 0.6798 - val_loss: 0.6315 - val_accuracy: 0.7862 - val_precision: 0.8090 - val_recall: 0.7426 - 9s/epoch - 14ms/step
# Epoch 4/15
# 618/618 - 9s - loss: 0.5986 - accuracy: 0.6963 - precision: 0.6879 - recall: 0.7201 - val_loss: 0.5781 - val_accuracy: 0.6746 - val_precision: 0.9302 - val_recall: 0.3690 - 9s/epoch - 14ms/step
# Epoch 5/15
# 618/618 - 10s - loss: 0.5273 - accuracy: 0.7859 - precision: 0.7873 - recall: 0.7841 - val_loss: 0.5381 - val_accuracy: 0.7033 - val_precision: 0.9270 - val_recall: 0.4336 - 10s/epoch - 16ms/step
# Epoch 6/15
# 618/618 - 9s - loss: 0.4676 - accuracy: 0.8226 - precision: 0.8324 - recall: 0.8085 - val_loss: 0.4827 - val_accuracy: 0.8213 - val_precision: 0.7759 - val_recall: 0.8976 - 9s/epoch - 14ms/step
# Epoch 7/15
# 618/618 - 10s - loss: 0.4152 - accuracy: 0.8552 - precision: 0.8626 - recall: 0.8456 - val_loss: 0.4505 - val_accuracy: 0.8295 - val_precision: 0.8785 - val_recall: 0.7601 - 10s/epoch - 16ms/step
# Epoch 8/15
# 618/618 - 9s - loss: 0.3770 - accuracy: 0.8681 - precision: 0.8741 - recall: 0.8606 - val_loss: 0.4529 - val_accuracy: 0.8254 - val_precision: 0.7728 - val_recall: 0.9161 - 9s/epoch - 14ms/step
# Epoch 9/15
# 618/618 - 9s - loss: 0.3423 - accuracy: 0.8805 - precision: 0.8866 - recall: 0.8731 - val_loss: 0.4701 - val_accuracy: 0.8049 - val_precision: 0.7373 - val_recall: 0.9400 - 9s/epoch - 15ms/step
# Epoch 10/15
# 618/618 - 9s - loss: 0.3175 - accuracy: 0.8882 - precision: 0.8947 - recall: 0.8803 - val_loss: 0.4187 - val_accuracy: 0.8528 - val_precision: 0.8277 - val_recall: 0.8865 - 9s/epoch - 15ms/step
# Epoch 11/15
# 618/618 - 13s - loss: 0.2906 - accuracy: 0.8998 - precision: 0.9040 - recall: 0.8949 - val_loss: 0.4336 - val_accuracy: 0.8268 - val_precision: 0.9103 - val_recall: 0.7205 - 13s/epoch - 21ms/step
# Epoch 12/15
# 618/618 - 12s - loss: 0.2765 - accuracy: 0.8987 - precision: 0.9033 - recall: 0.8932 - val_loss: 0.4077 - val_accuracy: 0.8624 - val_precision: 0.8696 - val_recall: 0.8487 - 12s/epoch - 20ms/step
# Epoch 13/15
# 618/618 - 12s - loss: 0.2474 - accuracy: 0.9179 - precision: 0.9223 - recall: 0.9130 - val_loss: 0.4082 - val_accuracy: 0.8646 - val_precision: 0.8613 - val_recall: 0.8653 - 12s/epoch - 20ms/step
# Epoch 14/15
# 618/618 - 9s - loss: 0.2335 - accuracy: 0.9206 - precision: 0.9258 - recall: 0.9147 - val_loss: 0.4079 - val_accuracy: 0.8655 - val_precision: 0.8768 - val_recall: 0.8469 - 9s/epoch - 15ms/step
# Epoch 15/15
# 618/618 - 9s - loss: 0.2184 - accuracy: 0.9240 - precision: 0.9290 - recall: 0.9185 - val_loss: 0.4165 - val_accuracy: 0.8578 - val_precision: 0.9038 - val_recall: 0.7970 - 9s/epoch - 14ms/step
#               precision    recall  f1-score   support
#
#        False       0.82      0.92      0.87      1110
#         True       0.90      0.80      0.85      1084
#
#     accuracy                           0.86      2194
#    macro avg       0.86      0.86      0.86      2194
# weighted avg       0.86      0.86      0.86      2194
#
#              !!!!!  split number : 5  !!!!!
#      In training: Counter({False: 9893, True: 9855})
#      In testing: Counter({True: 1116, False: 1078})
# Epoch 1/15
# 618/618 - 10s - loss: 0.6931 - accuracy: 0.5052 - precision: 0.5046 - recall: 0.4601 - val_loss: 0.6921 - val_accuracy: 0.5146 - val_precision: 0.5118 - val_recall: 0.9910 - 10s/epoch - 16ms/step
# Epoch 2/15
# 618/618 - 9s - loss: 0.6872 - accuracy: 0.5449 - precision: 0.5427 - recall: 0.5596 - val_loss: 0.6754 - val_accuracy: 0.7019 - val_precision: 0.6442 - val_recall: 0.9247 - 9s/epoch - 14ms/step
# Epoch 3/15
# 618/618 - 9s - loss: 0.6483 - accuracy: 0.6397 - precision: 0.6242 - recall: 0.6985 - val_loss: 0.6221 - val_accuracy: 0.5962 - val_precision: 0.5593 - val_recall: 0.9722 - 9s/epoch - 14ms/step
# Epoch 4/15
# 618/618 - 9s - loss: 0.5707 - accuracy: 0.7493 - precision: 0.7477 - recall: 0.7513 - val_loss: 0.5523 - val_accuracy: 0.8008 - val_precision: 0.8907 - val_recall: 0.6935 - 9s/epoch - 14ms/step
# Epoch 5/15
# 618/618 - 9s - loss: 0.4954 - accuracy: 0.8123 - precision: 0.8216 - recall: 0.7971 - val_loss: 0.5004 - val_accuracy: 0.8387 - val_precision: 0.8470 - val_recall: 0.8333 - 9s/epoch - 14ms/step
# Epoch 6/15
# 618/618 - 9s - loss: 0.4374 - accuracy: 0.8377 - precision: 0.8448 - recall: 0.8267 - val_loss: 0.5863 - val_accuracy: 0.6632 - val_precision: 0.6049 - val_recall: 0.9740 - 9s/epoch - 15ms/step
# Epoch 7/15
# 618/618 - 9s - loss: 0.3927 - accuracy: 0.8533 - precision: 0.8602 - recall: 0.8430 - val_loss: 0.5119 - val_accuracy: 0.7557 - val_precision: 0.6849 - val_recall: 0.9624 - 9s/epoch - 14ms/step
# Epoch 8/15
# 618/618 - 9s - loss: 0.3492 - accuracy: 0.8799 - precision: 0.8837 - recall: 0.8744 - val_loss: 0.4283 - val_accuracy: 0.8587 - val_precision: 0.8853 - val_recall: 0.8297 - 9s/epoch - 14ms/step
# Epoch 9/15
# 618/618 - 9s - loss: 0.3220 - accuracy: 0.8838 - precision: 0.8898 - recall: 0.8757 - val_loss: 0.4147 - val_accuracy: 0.8655 - val_precision: 0.8668 - val_recall: 0.8692 - 9s/epoch - 15ms/step
# Epoch 10/15
# 618/618 - 9s - loss: 0.2928 - accuracy: 0.8944 - precision: 0.8981 - recall: 0.8894 - val_loss: 0.4185 - val_accuracy: 0.8537 - val_precision: 0.9162 - val_recall: 0.7841 - 9s/epoch - 15ms/step
# Epoch 11/15
# 618/618 - 9s - loss: 0.2684 - accuracy: 0.9061 - precision: 0.9098 - recall: 0.9012 - val_loss: 0.4081 - val_accuracy: 0.8733 - val_precision: 0.8938 - val_recall: 0.8522 - 9s/epoch - 15ms/step
# Epoch 12/15
# 618/618 - 9s - loss: 0.2464 - accuracy: 0.9124 - precision: 0.9182 - recall: 0.9052 - val_loss: 0.4439 - val_accuracy: 0.8418 - val_precision: 0.7880 - val_recall: 0.9427 - 9s/epoch - 14ms/step
# Epoch 13/15
# 618/618 - 9s - loss: 0.2298 - accuracy: 0.9192 - precision: 0.9219 - recall: 0.9157 - val_loss: 0.4185 - val_accuracy: 0.8692 - val_precision: 0.8378 - val_recall: 0.9211 - 9s/epoch - 14ms/step
# Epoch 14/15
# 618/618 - 9s - loss: 0.2139 - accuracy: 0.9241 - precision: 0.9281 - recall: 0.9192 - val_loss: 0.4389 - val_accuracy: 0.8582 - val_precision: 0.8172 - val_recall: 0.9292 - 9s/epoch - 14ms/step
# Epoch 15/15
# 618/618 - 9s - loss: 0.2025 - accuracy: 0.9278 - precision: 0.9298 - recall: 0.9253 - val_loss: 0.4120 - val_accuracy: 0.8810 - val_precision: 0.8947 - val_recall: 0.8683 - 9s/epoch - 15ms/step
#               precision    recall  f1-score   support
#
#        False       0.87      0.89      0.88      1078
#         True       0.89      0.87      0.88      1116
#
#     accuracy                           0.88      2194
#    macro avg       0.88      0.88      0.88      2194
# weighted avg       0.88      0.88      0.88      2194
#
#              !!!!!  split number : 6  !!!!!
#      In training: Counter({False: 9877, True: 9871})
#      In testing: Counter({True: 1100, False: 1094})
# Epoch 1/15
# 618/618 - 10s - loss: 0.6931 - accuracy: 0.5044 - precision: 0.5036 - recall: 0.6014 - val_loss: 0.6929 - val_accuracy: 0.4986 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - 10s/epoch - 16ms/step
# Epoch 2/15
# 618/618 - 9s - loss: 0.6906 - accuracy: 0.5319 - precision: 0.5359 - recall: 0.4737 - val_loss: 0.6863 - val_accuracy: 0.5337 - val_precision: 0.5186 - val_recall: 0.9782 - 9s/epoch - 14ms/step
# Epoch 3/15
# 618/618 - 9s - loss: 0.6708 - accuracy: 0.5953 - precision: 0.5886 - recall: 0.6325 - val_loss: 0.6536 - val_accuracy: 0.5620 - val_precision: 0.5347 - val_recall: 0.9727 - 9s/epoch - 14ms/step
# Epoch 4/15
# 618/618 - 9s - loss: 0.6201 - accuracy: 0.7085 - precision: 0.6986 - recall: 0.7333 - val_loss: 0.5913 - val_accuracy: 0.7789 - val_precision: 0.8773 - val_recall: 0.6500 - 9s/epoch - 14ms/step
# Epoch 5/15
# 618/618 - 11s - loss: 0.5627 - accuracy: 0.7616 - precision: 0.7653 - recall: 0.7545 - val_loss: 0.5463 - val_accuracy: 0.7685 - val_precision: 0.7016 - val_recall: 0.9364 - 11s/epoch - 17ms/step
# Epoch 6/15
# 618/618 - 14s - loss: 0.5083 - accuracy: 0.8091 - precision: 0.8172 - recall: 0.7963 - val_loss: 0.5072 - val_accuracy: 0.8095 - val_precision: 0.7599 - val_recall: 0.9064 - 14s/epoch - 23ms/step
# Epoch 7/15
# 618/618 - 10s - loss: 0.4608 - accuracy: 0.8341 - precision: 0.8401 - recall: 0.8250 - val_loss: 0.4974 - val_accuracy: 0.7621 - val_precision: 0.9048 - val_recall: 0.5873 - 10s/epoch - 15ms/step
# Epoch 8/15
# 618/618 - 9s - loss: 0.4218 - accuracy: 0.8509 - precision: 0.8584 - recall: 0.8403 - val_loss: 0.4504 - val_accuracy: 0.8418 - val_precision: 0.8575 - val_recall: 0.8209 - 9s/epoch - 14ms/step
# Epoch 9/15
# 618/618 - 9s - loss: 0.3842 - accuracy: 0.8672 - precision: 0.8731 - recall: 0.8591 - val_loss: 0.4375 - val_accuracy: 0.8437 - val_precision: 0.8120 - val_recall: 0.8955 - 9s/epoch - 15ms/step
# Epoch 10/15
# 618/618 - 9s - loss: 0.3533 - accuracy: 0.8793 - precision: 0.8842 - recall: 0.8729 - val_loss: 0.4222 - val_accuracy: 0.8569 - val_precision: 0.8394 - val_recall: 0.8836 - 9s/epoch - 15ms/step
# Epoch 11/15
# 618/618 - 9s - loss: 0.3268 - accuracy: 0.8883 - precision: 0.8935 - recall: 0.8817 - val_loss: 0.4103 - val_accuracy: 0.8496 - val_precision: 0.8789 - val_recall: 0.8118 - 9s/epoch - 14ms/step
# Epoch 12/15
# 618/618 - 9s - loss: 0.3016 - accuracy: 0.8981 - precision: 0.9025 - recall: 0.8925 - val_loss: 0.4003 - val_accuracy: 0.8605 - val_precision: 0.8609 - val_recall: 0.8609 - 9s/epoch - 14ms/step
# Epoch 13/15
# 618/618 - 9s - loss: 0.2814 - accuracy: 0.9031 - precision: 0.9068 - recall: 0.8985 - val_loss: 0.4457 - val_accuracy: 0.8108 - val_precision: 0.9182 - val_recall: 0.6836 - 9s/epoch - 14ms/step
# Epoch 14/15
# 618/618 - 9s - loss: 0.2607 - accuracy: 0.9104 - precision: 0.9139 - recall: 0.9060 - val_loss: 0.3909 - val_accuracy: 0.8637 - val_precision: 0.8624 - val_recall: 0.8664 - 9s/epoch - 15ms/step
# Epoch 15/15
# 618/618 - 9s - loss: 0.2442 - accuracy: 0.9166 - precision: 0.9214 - recall: 0.9108 - val_loss: 0.4103 - val_accuracy: 0.8528 - val_precision: 0.8101 - val_recall: 0.9227 - 9s/epoch - 14ms/step
#               precision    recall  f1-score   support
#
#        False       0.91      0.78      0.84      1094
#         True       0.81      0.92      0.86      1100
#
#     accuracy                           0.85      2194
#    macro avg       0.86      0.85      0.85      2194
# weighted avg       0.86      0.85      0.85      2194
#
#              !!!!!  split number : 7  !!!!!
#      In training: Counter({True: 9875, False: 9873})
#      In testing: Counter({False: 1098, True: 1096})
# Epoch 1/15
# 618/618 - 10s - loss: 0.6930 - accuracy: 0.5048 - precision: 0.5047 - recall: 0.5267 - val_loss: 0.6920 - val_accuracy: 0.5005 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - 10s/epoch - 17ms/step
# Epoch 2/15
# 618/618 - 9s - loss: 0.6863 - accuracy: 0.5578 - precision: 0.5518 - recall: 0.6169 - val_loss: 0.6831 - val_accuracy: 0.5278 - val_precision: 0.5146 - val_recall: 0.9635 - 9s/epoch - 15ms/step
# Epoch 3/15
# 618/618 - 9s - loss: 0.6452 - accuracy: 0.6379 - precision: 0.6160 - recall: 0.7327 - val_loss: 0.6260 - val_accuracy: 0.6144 - val_precision: 0.9464 - val_recall: 0.2418 - 9s/epoch - 14ms/step
# Epoch 4/15
# 618/618 - 9s - loss: 0.5655 - accuracy: 0.7611 - precision: 0.7577 - recall: 0.7679 - val_loss: 0.5520 - val_accuracy: 0.7885 - val_precision: 0.7465 - val_recall: 0.8732 - 9s/epoch - 14ms/step
# Epoch 5/15
# 618/618 - 9s - loss: 0.4946 - accuracy: 0.8084 - precision: 0.8120 - recall: 0.8026 - val_loss: 0.5092 - val_accuracy: 0.7917 - val_precision: 0.9091 - val_recall: 0.6478 - 9s/epoch - 14ms/step
# Epoch 6/15
# 618/618 - 9s - loss: 0.4333 - accuracy: 0.8456 - precision: 0.8510 - recall: 0.8379 - val_loss: 0.4803 - val_accuracy: 0.8004 - val_precision: 0.9062 - val_recall: 0.6697 - 9s/epoch - 14ms/step
# Epoch 7/15
# 618/618 - 9s - loss: 0.3885 - accuracy: 0.8627 - precision: 0.8675 - recall: 0.8563 - val_loss: 0.4500 - val_accuracy: 0.8336 - val_precision: 0.8977 - val_recall: 0.7527 - 9s/epoch - 14ms/step
# Epoch 8/15
# 618/618 - 9s - loss: 0.3525 - accuracy: 0.8754 - precision: 0.8807 - recall: 0.8686 - val_loss: 0.4288 - val_accuracy: 0.8537 - val_precision: 0.8926 - val_recall: 0.8038 - 9s/epoch - 14ms/step
# Epoch 9/15
# 618/618 - 9s - loss: 0.3187 - accuracy: 0.8898 - precision: 0.8944 - recall: 0.8838 - val_loss: 0.4178 - val_accuracy: 0.8560 - val_precision: 0.8924 - val_recall: 0.8093 - 9s/epoch - 14ms/step
# Epoch 10/15
# 618/618 - 9s - loss: 0.2938 - accuracy: 0.8980 - precision: 0.9013 - recall: 0.8940 - val_loss: 0.4502 - val_accuracy: 0.8177 - val_precision: 0.7609 - val_recall: 0.9261 - 9s/epoch - 14ms/step
# Epoch 11/15
# 618/618 - 9s - loss: 0.2718 - accuracy: 0.9044 - precision: 0.9089 - recall: 0.8989 - val_loss: 0.4123 - val_accuracy: 0.8523 - val_precision: 0.8180 - val_recall: 0.9060 - 9s/epoch - 14ms/step
# Epoch 12/15
# 618/618 - 9s - loss: 0.2462 - accuracy: 0.9142 - precision: 0.9169 - recall: 0.9110 - val_loss: 0.4107 - val_accuracy: 0.8514 - val_precision: 0.8171 - val_recall: 0.9051 - 9s/epoch - 14ms/step
# Epoch 13/15
# 618/618 - 10s - loss: 0.2282 - accuracy: 0.9219 - precision: 0.9268 - recall: 0.9161 - val_loss: 0.3927 - val_accuracy: 0.8715 - val_precision: 0.9014 - val_recall: 0.8339 - 10s/epoch - 16ms/step
# Epoch 14/15
# 618/618 - 9s - loss: 0.2141 - accuracy: 0.9261 - precision: 0.9313 - recall: 0.9201 - val_loss: 0.4568 - val_accuracy: 0.8254 - val_precision: 0.7666 - val_recall: 0.9352 - 9s/epoch - 14ms/step
# Epoch 15/15
# 618/618 - 9s - loss: 0.2053 - accuracy: 0.9268 - precision: 0.9317 - recall: 0.9211 - val_loss: 0.3897 - val_accuracy: 0.8801 - val_precision: 0.8889 - val_recall: 0.8686 - 9s/epoch - 14ms/step
#               precision    recall  f1-score   support
#
#        False       0.87      0.89      0.88      1098
#         True       0.89      0.87      0.88      1096
#
#     accuracy                           0.88      2194
#    macro avg       0.88      0.88      0.88      2194
# weighted avg       0.88      0.88      0.88      2194
#
#              !!!!!  split number : 8  !!!!!
#      In training: Counter({False: 9898, True: 9850})
#      In testing: Counter({True: 1121, False: 1073})
# Epoch 1/15
# 618/618 - 10s - loss: 0.6930 - accuracy: 0.5082 - precision: 0.5048 - recall: 0.7334 - val_loss: 0.6963 - val_accuracy: 0.4891 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - 10s/epoch - 16ms/step
# Epoch 2/15
# 618/618 - 9s - loss: 0.6899 - accuracy: 0.5343 - precision: 0.5396 - recall: 0.4521 - val_loss: 0.6836 - val_accuracy: 0.6322 - val_precision: 0.5892 - val_recall: 0.9251 - 9s/epoch - 14ms/step
# Epoch 3/15
# 618/618 - 9s - loss: 0.6615 - accuracy: 0.6241 - precision: 0.6101 - recall: 0.6825 - val_loss: 0.6343 - val_accuracy: 0.6267 - val_precision: 0.5813 - val_recall: 0.9634 - 9s/epoch - 14ms/step
# Epoch 4/15
# 618/618 - 9s - loss: 0.5895 - accuracy: 0.7308 - precision: 0.7258 - recall: 0.7396 - val_loss: 0.5641 - val_accuracy: 0.8186 - val_precision: 0.8025 - val_recall: 0.8555 - 9s/epoch - 15ms/step
# Epoch 5/15
# 618/618 - 10s - loss: 0.5108 - accuracy: 0.8065 - precision: 0.8149 - recall: 0.7920 - val_loss: 0.5164 - val_accuracy: 0.8058 - val_precision: 0.9074 - val_recall: 0.6905 - 10s/epoch - 16ms/step
# Epoch 6/15
# 618/618 - 9s - loss: 0.4463 - accuracy: 0.8362 - precision: 0.8431 - recall: 0.8252 - val_loss: 0.4848 - val_accuracy: 0.8204 - val_precision: 0.9061 - val_recall: 0.7235 - 9s/epoch - 15ms/step
# Epoch 7/15
# 618/618 - 9s - loss: 0.3960 - accuracy: 0.8593 - precision: 0.8648 - recall: 0.8510 - val_loss: 0.4616 - val_accuracy: 0.8446 - val_precision: 0.9054 - val_recall: 0.7770 - 9s/epoch - 14ms/step
# Epoch 8/15
# 618/618 - 10s - loss: 0.3573 - accuracy: 0.8719 - precision: 0.8771 - recall: 0.8644 - val_loss: 0.4670 - val_accuracy: 0.8245 - val_precision: 0.7771 - val_recall: 0.9206 - 10s/epoch - 16ms/step
# Epoch 9/15
# 618/618 - 9s - loss: 0.3234 - accuracy: 0.8870 - precision: 0.8916 - recall: 0.8806 - val_loss: 0.4734 - val_accuracy: 0.8204 - val_precision: 0.7687 - val_recall: 0.9277 - 9s/epoch - 14ms/step
# Epoch 10/15
# 618/618 - 9s - loss: 0.2978 - accuracy: 0.8946 - precision: 0.8985 - recall: 0.8891 - val_loss: 0.4341 - val_accuracy: 0.8619 - val_precision: 0.8759 - val_recall: 0.8501 - 9s/epoch - 14ms/step
# Epoch 11/15
# 618/618 - 9s - loss: 0.2710 - accuracy: 0.9062 - precision: 0.9101 - recall: 0.9009 - val_loss: 0.4963 - val_accuracy: 0.8168 - val_precision: 0.7611 - val_recall: 0.9349 - 9s/epoch - 14ms/step
# Epoch 12/15
# 618/618 - 9s - loss: 0.2532 - accuracy: 0.9111 - precision: 0.9161 - recall: 0.9047 - val_loss: 0.4400 - val_accuracy: 0.8642 - val_precision: 0.8900 - val_recall: 0.8376 - 9s/epoch - 14ms/step
# Epoch 13/15
# 618/618 - 9s - loss: 0.2290 - accuracy: 0.9217 - precision: 0.9272 - recall: 0.9148 - val_loss: 0.5139 - val_accuracy: 0.8236 - val_precision: 0.9379 - val_recall: 0.7012 - 9s/epoch - 14ms/step
# Epoch 14/15
# 618/618 - 9s - loss: 0.2173 - accuracy: 0.9234 - precision: 0.9278 - recall: 0.9178 - val_loss: 0.4768 - val_accuracy: 0.8455 - val_precision: 0.9259 - val_recall: 0.7583 - 9s/epoch - 14ms/step
# Epoch 15/15
# 618/618 - 9s - loss: 0.2003 - accuracy: 0.9304 - precision: 0.9322 - recall: 0.9280 - val_loss: 0.5252 - val_accuracy: 0.8268 - val_precision: 0.9405 - val_recall: 0.7056 - 9s/epoch - 14ms/step
#               precision    recall  f1-score   support
#
#        False       0.76      0.95      0.84      1073
#         True       0.94      0.71      0.81      1121
#
#     accuracy                           0.83      2194
#    macro avg       0.85      0.83      0.82      2194
# weighted avg       0.85      0.83      0.82      2194
#
#              !!!!!  split number : 9  !!!!!
#      In training: Counter({True: 9887, False: 9861})
#      In testing: Counter({False: 1110, True: 1084})
# Epoch 1/15
# 618/618 - 11s - loss: 0.6930 - accuracy: 0.5153 - precision: 0.5140 - recall: 0.5861 - val_loss: 0.6922 - val_accuracy: 0.5351 - val_precision: 0.5157 - val_recall: 0.9677 - 11s/epoch - 17ms/step
# Epoch 2/15
# 618/618 - 9s - loss: 0.6877 - accuracy: 0.5461 - precision: 0.5400 - recall: 0.6315 - val_loss: 0.6761 - val_accuracy: 0.5570 - val_precision: 0.5288 - val_recall: 0.9493 - 9s/epoch - 15ms/step
# Epoch 3/15
# 618/618 - 9s - loss: 0.6538 - accuracy: 0.6375 - precision: 0.6290 - recall: 0.6730 - val_loss: 0.6312 - val_accuracy: 0.5729 - val_precision: 0.5376 - val_recall: 0.9686 - 9s/epoch - 14ms/step
# Epoch 4/15
# 618/618 - 9s - loss: 0.5866 - accuracy: 0.7317 - precision: 0.7277 - recall: 0.7418 - val_loss: 0.5612 - val_accuracy: 0.7995 - val_precision: 0.8762 - val_recall: 0.6919 - 9s/epoch - 14ms/step
# Epoch 5/15
# 618/618 - 9s - loss: 0.5129 - accuracy: 0.7978 - precision: 0.8029 - recall: 0.7899 - val_loss: 0.5130 - val_accuracy: 0.8218 - val_precision: 0.8690 - val_recall: 0.7528 - 9s/epoch - 14ms/step
# Epoch 6/15
# 618/618 - 9s - loss: 0.4519 - accuracy: 0.8375 - precision: 0.8446 - recall: 0.8277 - val_loss: 0.4809 - val_accuracy: 0.8309 - val_precision: 0.7925 - val_recall: 0.8911 - 9s/epoch - 14ms/step
# Epoch 7/15
# 618/618 - 9s - loss: 0.4024 - accuracy: 0.8582 - precision: 0.8629 - recall: 0.8520 - val_loss: 0.4778 - val_accuracy: 0.8045 - val_precision: 0.9259 - val_recall: 0.6568 - 9s/epoch - 15ms/step
# Epoch 8/15
# 618/618 - 9s - loss: 0.3629 - accuracy: 0.8726 - precision: 0.8798 - recall: 0.8635 - val_loss: 0.4386 - val_accuracy: 0.8523 - val_precision: 0.8792 - val_recall: 0.8127 - 9s/epoch - 14ms/step
# Epoch 9/15
# 618/618 - 9s - loss: 0.3260 - accuracy: 0.8865 - precision: 0.8928 - recall: 0.8787 - val_loss: 0.4818 - val_accuracy: 0.7972 - val_precision: 0.7284 - val_recall: 0.9400 - 9s/epoch - 14ms/step
# Epoch 10/15
# 618/618 - 9s - loss: 0.2968 - accuracy: 0.8972 - precision: 0.9012 - recall: 0.8924 - val_loss: 0.4246 - val_accuracy: 0.8573 - val_precision: 0.8890 - val_recall: 0.8127 - 9s/epoch - 14ms/step
# Epoch 11/15
# 618/618 - 9s - loss: 0.2734 - accuracy: 0.9043 - precision: 0.9074 - recall: 0.9009 - val_loss: 0.4199 - val_accuracy: 0.8633 - val_precision: 0.8577 - val_recall: 0.8672 - 9s/epoch - 14ms/step
# Epoch 12/15
# 618/618 - 9s - loss: 0.2535 - accuracy: 0.9129 - precision: 0.9153 - recall: 0.9102 - val_loss: 0.4294 - val_accuracy: 0.8496 - val_precision: 0.8190 - val_recall: 0.8930 - 9s/epoch - 14ms/step
# Epoch 13/15
# 618/618 - 9s - loss: 0.2330 - accuracy: 0.9185 - precision: 0.9223 - recall: 0.9142 - val_loss: 0.4231 - val_accuracy: 0.8646 - val_precision: 0.8620 - val_recall: 0.8644 - 9s/epoch - 15ms/step
# Epoch 14/15
# 618/618 - 9s - loss: 0.2140 - accuracy: 0.9286 - precision: 0.9312 - recall: 0.9258 - val_loss: 0.4263 - val_accuracy: 0.8678 - val_precision: 0.8825 - val_recall: 0.8450 - 9s/epoch - 14ms/step
# Epoch 15/15
# 618/618 - 9s - loss: 0.2032 - accuracy: 0.9292 - precision: 0.9325 - recall: 0.9256 - val_loss: 0.4383 - val_accuracy: 0.8596 - val_precision: 0.8351 - val_recall: 0.8921 - 9s/epoch - 14ms/step
#               precision    recall  f1-score   support
#
#        False       0.89      0.83      0.86      1110
#         True       0.84      0.89      0.86      1084
#
#     accuracy                           0.86      2194
#    macro avg       0.86      0.86      0.86      2194
# weighted avg       0.86      0.86      0.86      2194
#
#              !!!!!  split number : 10  !!!!!
#      In training: Counter({False: 9893, True: 9855})
#      In testing: Counter({True: 1116, False: 1078})
# Epoch 1/15
# 618/618 - 11s - loss: 0.6930 - accuracy: 0.5042 - precision: 0.5034 - recall: 0.4824 - val_loss: 0.6926 - val_accuracy: 0.4927 - val_precision: 0.8000 - val_recall: 0.0036 - 11s/epoch - 17ms/step
# Epoch 2/15
# 618/618 - 9s - loss: 0.6884 - accuracy: 0.5411 - precision: 0.5393 - recall: 0.5517 - val_loss: 0.6804 - val_accuracy: 0.5469 - val_precision: 0.5296 - val_recall: 0.9794 - 9s/epoch - 14ms/step
# Epoch 3/15
# 618/618 - 9s - loss: 0.6542 - accuracy: 0.6365 - precision: 0.6260 - recall: 0.6746 - val_loss: 0.6437 - val_accuracy: 0.5830 - val_precision: 0.9548 - val_recall: 0.1891 - 9s/epoch - 14ms/step
# Epoch 4/15
# 618/618 - 9s - loss: 0.5898 - accuracy: 0.7392 - precision: 0.7369 - recall: 0.7426 - val_loss: 0.5728 - val_accuracy: 0.7990 - val_precision: 0.7968 - val_recall: 0.8118 - 9s/epoch - 14ms/step
# Epoch 5/15
# 618/618 - 10s - loss: 0.5228 - accuracy: 0.7935 - precision: 0.7947 - recall: 0.7904 - val_loss: 0.5290 - val_accuracy: 0.8067 - val_precision: 0.8604 - val_recall: 0.7401 - 10s/epoch - 16ms/step
# Epoch 6/15
# 618/618 - 9s - loss: 0.4655 - accuracy: 0.8274 - precision: 0.8332 - recall: 0.8179 - val_loss: 0.5072 - val_accuracy: 0.7862 - val_precision: 0.7306 - val_recall: 0.9185 - 9s/epoch - 15ms/step
# Epoch 7/15
# 618/618 - 9s - loss: 0.4165 - accuracy: 0.8517 - precision: 0.8564 - recall: 0.8443 - val_loss: 0.4857 - val_accuracy: 0.8067 - val_precision: 0.7567 - val_recall: 0.9140 - 9s/epoch - 14ms/step
# Epoch 8/15
# 618/618 - 9s - loss: 0.3772 - accuracy: 0.8668 - precision: 0.8731 - recall: 0.8576 - val_loss: 0.4538 - val_accuracy: 0.8482 - val_precision: 0.8588 - val_recall: 0.8396 - 9s/epoch - 14ms/step
# Epoch 9/15
# 618/618 - 9s - loss: 0.3443 - accuracy: 0.8788 - precision: 0.8837 - recall: 0.8718 - val_loss: 0.4406 - val_accuracy: 0.8523 - val_precision: 0.8687 - val_recall: 0.8360 - 9s/epoch - 14ms/step
# Epoch 10/15
# 618/618 - 9s - loss: 0.3158 - accuracy: 0.8906 - precision: 0.8938 - recall: 0.8860 - val_loss: 0.4383 - val_accuracy: 0.8469 - val_precision: 0.8963 - val_recall: 0.7903 - 9s/epoch - 15ms/step
# Epoch 11/15
# 618/618 - 9s - loss: 0.2915 - accuracy: 0.8979 - precision: 0.9044 - recall: 0.8895 - val_loss: 0.4394 - val_accuracy: 0.8473 - val_precision: 0.8162 - val_recall: 0.9032 - 9s/epoch - 15ms/step
# Epoch 12/15
# 618/618 - 10s - loss: 0.2697 - accuracy: 0.9074 - precision: 0.9131 - recall: 0.9002 - val_loss: 0.4277 - val_accuracy: 0.8564 - val_precision: 0.8363 - val_recall: 0.8925 - 10s/epoch - 16ms/step
# Epoch 13/15
# 618/618 - 9s - loss: 0.2506 - accuracy: 0.9136 - precision: 0.9190 - recall: 0.9066 - val_loss: 0.4295 - val_accuracy: 0.8578 - val_precision: 0.8367 - val_recall: 0.8952 - 9s/epoch - 14ms/step
# Epoch 14/15
# 618/618 - 9s - loss: 0.2344 - accuracy: 0.9210 - precision: 0.9265 - recall: 0.9143 - val_loss: 0.4246 - val_accuracy: 0.8642 - val_precision: 0.8490 - val_recall: 0.8916 - 9s/epoch - 15ms/step
# Epoch 15/15
# 618/618 - 9s - loss: 0.2214 - accuracy: 0.9239 - precision: 0.9272 - recall: 0.9197 - val_loss: 0.4156 - val_accuracy: 0.8665 - val_precision: 0.8886 - val_recall: 0.8432 - 9s/epoch - 15ms/step
#               precision    recall  f1-score   support
#
#        False       0.85      0.89      0.87      1078
#         True       0.89      0.84      0.87      1116
#
#     accuracy                           0.87      2194
#    macro avg       0.87      0.87      0.87      2194
# weighted avg       0.87      0.87      0.87      2194
#
# mean accuracy for this sub_experiment is 0.87
# mean recall for this sub_experiment is 0.86
# mean precision for this sub_experiment is 0.88
# mean f1_score for this sub_experiment is 0.86
# ------------------------------------------------------------
# !!!!!  sub-experiment with keras sequential model number 2  !!!!!
# !!!!!  dataset used is : article and tweets without cleaning  !!!!!
# ------------------------------------------------------------
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-d56085e77361> in <module>()
#      39     #create the tokenizer and fit the tokenizer dictionary
#      40     tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
# ---> 41     tokenizer.fit_on_texts(dataSet_text[train])
#      42     #convert texts to sequences
#      43     training_sequences = tokenizer.texts_to_sequences(dataSet_text[train])
#
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/text.py in fit_on_texts(self, texts)
#     223                                             self.filters,
#     224                                             self.lower,
# --> 225                                             self.split)
#     226             for w in seq:
#     227                 if w in self.word_counts:
#
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/text.py in text_to_word_sequence(text, filters, lower, split)
#      41     """
#      42     if lower:
# ---> 43         text = text.lower()
#      44
#      45     if sys.version_info < (3,):
#
# AttributeError: 'float' object has no attribute 'lower'

# %% [markdown]
# # Model description

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_9 (Embedding)     (None, 2000, 18)          810000
#
#  global_average_pooling1d_9   (None, 18)               0
#  (GlobalAveragePooling1D)
#
#  dense_18 (Dense)            (None, 24)                456
#
#  dense_19 (Dense)            (None, 1)                 25
#
# =================================================================
# Total params: 810,481
# Trainable params: 810,481
# Non-trainable params: 0
# _________________________________________________________________
